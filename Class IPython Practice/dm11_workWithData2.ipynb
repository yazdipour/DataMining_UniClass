# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %% [markdown]
# # Aggregation

# %%
#Download file "winequality-red.csv" from following repository 
#and save it in the current directory
url = "http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/"

# %%
#Data are seperated by ";" not ","
dframe_wine = pd.read_csv("winequality-red.csv", sep=";")

# %%
dframe_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
dframe_wine['alcohol'].mean()
# Out:
# 10.422983114446502

# %%
dframe_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
wineGroupby = dframe_wine.groupby("quality")
wineGroupby.describe()
# Out:
#                   alcohol   chlorides  citric acid     density  fixed acidity  \
# quality
# 3       count   10.000000   10.000000    10.000000   10.000000      10.000000
#         mean     9.955000    0.122500     0.171000    0.997464       8.360000
#         std      0.818009    0.066241     0.250664    0.002002       1.770875
#         min      8.400000    0.061000     0.000000    0.994710       6.700000
#         25%      9.725000    0.079000     0.005000    0.996150       7.150000
#         50%      9.925000    0.090500     0.035000    0.997565       7.500000
#         75%     10.575000    0.143000     0.327500    0.998770       9.875000
#         max     11.000000    0.267000     0.660000    1.000800      11.600000
# 4       count   53.000000   53.000000    53.000000   53.000000      53.000000
#         mean    10.265094    0.090679     0.174151    0.996542       7.779245
#         std      0.934776    0.076192     0.201030    0.001575       1.626624
# ...

# %%
wineGroupby.mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             8.360000          0.884500     0.171000        2.635000
# 4             7.779245          0.693962     0.174151        2.694340
# 5             8.167254          0.577041     0.243686        2.528855
# 6             8.347179          0.497484     0.273824        2.477194
# 7             8.872362          0.403920     0.375176        2.720603
# 8             8.566667          0.423333     0.391111        2.577778
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.122500            11.000000             24.900000  0.997464
# 4         0.090679            12.264151             36.245283  0.996542
# 5         0.092736            16.983847             56.513950  0.997104
# 6         0.084956            15.711599             40.869906  0.996615
# 7         0.076588            14.045226             35.020101  0.996104
# ...

# %%
wineGroupby.agg('mean')
#The same as the previous cell
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             8.360000          0.884500     0.171000        2.635000
# 4             7.779245          0.693962     0.174151        2.694340
# 5             8.167254          0.577041     0.243686        2.528855
# 6             8.347179          0.497484     0.273824        2.477194
# 7             8.872362          0.403920     0.375176        2.720603
# 8             8.566667          0.423333     0.391111        2.577778
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.122500            11.000000             24.900000  0.997464
# 4         0.090679            12.264151             36.245283  0.996542
# 5         0.092736            16.983847             56.513950  0.997104
# 6         0.084956            15.711599             40.869906  0.996615
# 7         0.076588            14.045226             35.020101  0.996104
# ...

# %%
def max_to_min(arr):
    return arr.max() - arr.min()

# %%
wineGroupby.agg(max_to_min)
#applies the function to each column of the group
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3                  4.9             1.140         0.66             4.5
# 4                  7.9             0.900         1.00            11.6
# 5                 10.9             1.150         0.79            14.3
# 6                  9.6             0.880         0.78            14.5
# 7                 10.7             0.795         0.76             7.7
# 8                  7.6             0.590         0.69             5.0
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# quality
# 3            0.206                 31.0                  40.0  0.00609  0.47
# 4            0.565                 38.0                 112.0  0.00760  1.16
# 5            0.572                 65.0                 149.0  0.01059  0.86
# 6            0.381                 71.0                 159.0  0.01362  1.15
# ...

# %%
dframe_wine['qual/alc ratio'] = dframe_wine['quality'] / dframe_wine['alcohol']

# %%
dframe_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  qual/alc ratio
# 0      9.4        5        0.531915
# ...

# %%
dframe_wine.pivot_table(index='quality') 
#The same as dframe_wine.groupby("quality").mean()
# Out:
#            alcohol  chlorides  citric acid   density  fixed acidity  \
# quality
# 3         9.955000   0.122500     0.171000  0.997464       8.360000
# 4        10.265094   0.090679     0.174151  0.996542       7.779245
# 5         9.899706   0.092736     0.243686  0.997104       8.167254
# 6        10.629519   0.084956     0.273824  0.996615       8.347179
# 7        11.465913   0.076588     0.375176  0.996104       8.872362
# 8        12.094444   0.068444     0.391111  0.995212       8.566667
#
#          free sulfur dioxide        pH  qual/alc ratio  residual sugar  \
# quality
# 3                  11.000000  3.398000        0.303286        2.635000
# 4                  12.264151  3.381509        0.392724        2.694340
# 5                  16.983847  3.304949        0.507573        2.528855
# 6                  15.711599  3.318072        0.569801        2.477194
# 7                  14.045226  3.290754        0.614855        2.720603
# ...

# %%
# %matplotlib inline

# %%
dframe_wine.plot(kind='scatter', x='quality', y='alcohol')

# %% [markdown]
# # Split, Apply, Combine

# %%
myFrame = DataFrame({"A":[1, 2, 3, 1, 1], "B":[4, 5, 6, 7, 8], "C":[10, 20, 30, 40, 50]})
myFrame
# Out:
#    A  B   C
# 0  1  4  10
# 1  2  5  20
# 2  3  6  30
# 3  1  7  40
# 4  1  8  50

# %%
#apply the function to each group (which is a dataframe)
#DataFrame.shape gives a tuple of (nrows, ncolumns) of the frame
myFrame.groupby("A").apply(lambda x: x * x.shape[0])
# Out:
#    A   B    C
# 0  3  12   30
# 1  2   5   20
# 2  3   6   30
# 3  3  21  120
# 4  3  24  150

# %% [markdown]
# #### Work with real data
# #### Question: Find the wine with the most alcohol content in each quality group

# %% [markdown]
# #### First solution

# %%
dframe_wine.sort_values(by='alcohol', ascending = False, inplace = True)

# %%
def ranker(df):
    df['alc_content_rank'] = np.arange(len(df)) + 1
    return df

# %%
#Rank each quality group based on their alcohol contents
dframe_wine = dframe_wine.groupby('quality').apply(ranker)

# %%
dframe_wine.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 652            15.9              0.36         0.65             7.5      0.096
# 588             5.0              0.42         0.24             2.0      0.060
# 142             5.2              0.34         0.00             1.8      0.050
# 144             5.2              0.34         0.00             1.8      0.050
# 1270            5.0              0.38         0.01             1.6      0.048
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 652                  22.0                  71.0  0.99760  2.98       0.84
# 588                  19.0                  50.0  0.99170  3.72       0.74
# 142                  27.0                  63.0  0.99160  3.68       0.79
# 144                  27.0                  63.0  0.99160  3.68       0.79
# 1270                 26.0                  60.0  0.99084  3.70       0.75
#
# ...

# %%
num_of_qual = dframe_wine['quality'].value_counts()
num_of_qual
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
dframe_wine[dframe_wine.alc_content_rank == 1]
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 652           15.9              0.36         0.65             7.5      0.096
# 588            5.0              0.42         0.24             2.0      0.060
# 142            5.2              0.34         0.00             1.8      0.050
# 821            4.9              0.42         0.00             2.1      0.048
# 45             4.6              0.52         0.15             2.1      0.054
# 899            8.3              1.02         0.02             3.4      0.084
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 652                 22.0                  71.0  0.99760  2.98       0.84
# 588                 19.0                  50.0  0.99170  3.72       0.74
# 142                 27.0                  63.0  0.99160  3.68       0.79
# 821                 16.0                  42.0  0.99154  3.71       0.74
# ...

# %% [markdown]
# #### Second solution

# %%
dframe_wine = pd.read_csv("winequality-red.csv", sep=";")
dframe_wine.sort_values(by='alcohol', ascending = False, inplace = True)
dframe_wine.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 652            15.9              0.36         0.65             7.5      0.096
# 588             5.0              0.42         0.24             2.0      0.060
# 142             5.2              0.34         0.00             1.8      0.050
# 144             5.2              0.34         0.00             1.8      0.050
# 1270            5.0              0.38         0.01             1.6      0.048
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 652                  22.0                  71.0  0.99760  2.98       0.84
# 588                  19.0                  50.0  0.99170  3.72       0.74
# 142                  27.0                  63.0  0.99160  3.68       0.79
# 144                  27.0                  63.0  0.99160  3.68       0.79
# 1270                 26.0                  60.0  0.99084  3.70       0.75
#
#       alcohol  quality
# 652      14.9        5
# ...

# %%
resultsIndices = dframe_wine.groupby('quality').apply(lambda df: df['alcohol'].idxmax())
#resultsIndices.values.tolist()
dframe_wine.loc[resultsIndices.values.tolist(), :]
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 899            8.3              1.02         0.02             3.4      0.084
# 45             4.6              0.52         0.15             2.1      0.054
# 652           15.9              0.36         0.65             7.5      0.096
# 142            5.2              0.34         0.00             1.8      0.050
# 821            4.9              0.42         0.00             2.1      0.048
# 588            5.0              0.42         0.24             2.0      0.060
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 899                  6.0                  11.0  0.99892  3.48       0.49
# 45                   8.0                  65.0  0.99340  3.90       0.56
# 652                 22.0                  71.0  0.99760  2.98       0.84
# 142                 27.0                  63.0  0.99160  3.68       0.79
# ...

# %% [markdown]
# # Cross-Tabulation
# The main difference between the "pivot_table" and "crosstab" is the pivot_table expects your input data to already be a DataFrame; you pass a DataFrame to pivot_table and specify the index/columns/values by passing the column names as strings. With cross_tab, you don't necessarily need to have a DataFrame going in, as you just pass array-like objects for index/columns/values.
#
# Looking at the source code for crosstab, it essentially takes the array-like objects you pass, creates a DataFrame, then calls pivot_table as appropriate.

# %%
animalFrame = DataFrame({"Sample": range(1, 7), "Animal": ["Dog", "Dog", "Cat", "Cat", "Dog", "Cat"],
                        "Intelligence":["Smart", "Smart", "Dumb", "Dumb", "Dumb", "Smart"]})
animalFrame
# Out:
#   Animal Intelligence  Sample
# 0    Dog        Smart       1
# 1    Dog        Smart       2
# 2    Cat         Dumb       3
# 3    Cat         Dumb       4
# 4    Dog         Dumb       5
# 5    Cat        Smart       6

# %%
pd.crosstab(animalFrame.Animal, animalFrame.Intelligence, margins = True)
#pd.crosstab(animalFrame['Animal'], animalFrame['Intelligence'], margins = True)
# Out:
# Intelligence  Dumb  Smart  All
# Animal
# Cat              2      1    3
# Dog              1      2    3
# All              3      3    6

# %%
animalFrame.pivot_table(index = "Animal", columns = "Intelligence", aggfunc="count", margins=True)
# Out:
#              Sample
# Intelligence   Dumb Smart  All
# Animal
# Cat             2.0   1.0  3.0
# Dog             1.0   2.0  3.0
# All             3.0   3.0  6.0
